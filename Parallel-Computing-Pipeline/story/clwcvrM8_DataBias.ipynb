# %% [markdown]
# # Notebook for Module 8 Work
#
# This notebook contains information the following tasks for the Module 8 Work:
# * Exercise Part 4: Train the XGBoost ML Model
# * Exercise Part 3: Evaluate the ML model for data bias
# * Exercise Part 5: Complete the ML model fairness training
#
# The following headerss will seperate this work for grading in Jupyter.

# %%
import sys, os
old_stdout = sys.stdout
sys.stdout = open(os.devnull, "w")
# !{sys.executable} -m pip install -q fsspec;
# !{sys.executable} -m pip install -qU s3fs;
# !{sys.executable} -m pip install -qU scikit-learn;
# !{sys.executable} -m pip install -q awswrangler pandas;
# !{sys.executable} -m pip install -qU awscli boto3 "sagemaker==2.84.0";
sys.stdout = old_stdout

# %%
#Initialize SageMaker
from sagemaker import Session

session = Session()
bucket = "clwcvr-sagemaker"
prefix = "sagemaker/clwcvr_M8_DataBias"
region = session.boto_region_name

# Define IAM role
from sagemaker import get_execution_role
import pandas as pd
import numpy as np
import boto3

role = get_execution_role()
s3_client = boto3.client("s3")

# %% [markdown]
# ### Load data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
import io

df = pd.read_csv('s3://clwcvr-sagemaker/eshopclothing2008.csv')
df.head()
# Out:
#    year  month  day  order  country  session ID  page 1 (main category)  \
# 0  2008      4    1      1       29           1                       1
# 1  2008      4    1      2       29           1                       1
# 2  2008      4    1      3       29           1                       2
# 3  2008      4    1      4       29           1                       2
# 4  2008      4    1      5       29           1                       2
#
#   page 2 (clothing model)  colour  location  model photography  price  \
# 0                     A13       1         5                  1     28
# 1                     A16       1         6                  1     33
# 2                      B4      10         2                  1     52
# 3                     B17       6         6                  2     38
# 4                      B8       4         3                  2     52
#
#    price 2  page
# 0        2     1
# 1        2     1
# 2        1     1
# 3        2     1
# 4        1     1

# %%
#Replace all values as 2 in df['price 2'] column with 0
#When using model, you must use "0,1" for "no, yes" responses
df['price 2'] = df['price 2'].replace(2, 0)
df.head()
# Out:
#    year  month  day  order  country  session ID  page 1 (main category)  \
# 0  2008      4    1      1       29           1                       1
# 1  2008      4    1      2       29           1                       1
# 2  2008      4    1      3       29           1                       2
# 3  2008      4    1      4       29           1                       2
# 4  2008      4    1      5       29           1                       2
#
#   page 2 (clothing model)  colour  location  model photography  price  \
# 0                     A13       1         5                  1     28
# 1                     A16       1         6                  1     33
# 2                      B4      10         2                  1     52
# 3                     B17       6         6                  2     38
# 4                      B8       4         3                  2     52
#
#    price 2  page
# 0        0     1
# 1        0     1
# 2        1     1
# 3        0     1
# 4        1     1

# %%
training_data,testing_data = train_test_split(df, test_size=0.30, random_state=0)

# %% [markdown]
# ### Upload the Dataset

# %%
from sklearn import preprocessing

def number_encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            result[column] = encoders[column].fit_transform(result[column].fillna("None"))
    return result, encoders

training_data = pd.concat([training_data["price 2"], training_data.drop(["price 2"], axis=1)], axis=1)
training_data, _ = number_encode_features(training_data)
training_data.to_csv("train_data.csv", index=False, header=False)

testing_data, _ = number_encode_features(testing_data)
test_features = testing_data.drop(["price 2"], axis=1)
test_target = testing_data["price 2"]
test_features.to_csv("test_features.csv", index=False, header=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys

# %%
training_data.head()
# Out:
#         price 2  year  month  day  order  country  session ID  \
# 8736          0  2008      4    4      3        9        1268
# 55281         0  2008      5    7     13       29        8001
# 21348         1  2008      4   11      3        9        3109
# 122724        0  2008      7    7      1       29       18025
# 12771         0  2008      4    6     11       29        1860
#
#         page 1 (main category)  page 2 (clothing model)  colour  location  \
# 8736                         1                       38       3         2
# 55281                        4                      193      14         3
# 21348                        3                       89      14         1
# 122724                       2                       46       2         4
# 12771                        4                      138       4         4
#
#         model photography  price  page
# 8736                    1     43     1
# 55281                   2     28     4
# 21348                   1     57     2
# 122724                  1     38     1
# 12771                   1     33     1

# %%
from sagemaker.s3 import S3Uploader
from sagemaker.inputs import TrainingInput

train_uri = S3Uploader.upload("train_data.csv", "s3://{}/{}".format(bucket, prefix))
train_input = TrainingInput(train_uri, content_type="csv")
test_uri = S3Uploader.upload("test_features.csv", "s3://{}/{}".format(bucket, prefix))

# %% [markdown]
# ### Upload data to my S3 Bucket

# %% [markdown]
# ## Exercise Part 4: Train the XGBoost ML Model
# Use a standard XGBoost model.

# %%
from sagemaker.image_uris import retrieve
from sagemaker.estimator import Estimator

container = retrieve("xgboost", region, version="1.2-1")
xgb = Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    disable_profiler=True,
    sagemaker_session=session,
)

xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective="binary:logistic",
    num_round=800,
)

xgb.fit({"train": train_input}, logs=False)
# Out:
# 2022-04-22 02:31:47 Starting - Starting the training job...
# 2022-04-22 02:32:05 Starting - Preparing the instances for training................
# 2022-04-22 02:33:30 Downloading - Downloading input data...
# 2022-04-22 02:33:50 Training - Downloading the training image..........
# 2022-04-22 02:34:46 Training - Training image download completed. Training in progress.........
# 2022-04-22 02:35:31 Uploading - Uploading generated training model
# 2022-04-22 02:35:37 Completed - Training job completed

# %% [markdown]
# ## Create SageMaker Model

# %%
model_name = "clwcvr-Module8-Model"
model = xgb.create_model(name=model_name)
container_def = model.prepare_container_def()
session.create_model(model_name, role, container_def)
# Out:
# Using already existing model: clwcvr-Module8-Model
# 'clwcvr-Module8-Model'

# %% [markdown]
# ## View Amazon SageMaker Clarify

# %%
from sagemaker import clarify

clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=session
)

# %% [markdown]
# ## Exercise Part 3: Evaluate the ML model for Data Bias

# %%
bias_report_output_path = "s3://{}/{}/clwcvr-Module8-bias".format(bucket, prefix)
bias_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=bias_report_output_path,
    label="price 2",
    headers=training_data.columns.to_list(),
    dataset_type="text/csv",
)
# Out:
# DataConfig will be deprecated on 15 Mar 2022.s3_data_distribution_type parameter will no longer be supported. Everything else will remain as is in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
model_config = clarify.ModelConfig(
    model_name=model_name,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    accept_type="text/csv",
    content_type="text/csv",
)

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1], facet_name="model photography", facet_values_or_threshold=[0], group_name="price"
)

# %%
clarify_processor.run_bias(
    data_config=bias_data_config,
    bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predictions_config,
    pre_training_methods="all",
    post_training_methods="all",
)
# Out:
# Job Name:  Clarify-Bias-2022-04-22-02-35-39-359
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/train_data.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/clwcvr-Module8-bias/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/clwcvr-Module8-bias', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ..............................2022-04-22 02:40:26,988 logging.conf not found when configuring logging, using default logging configuration.
# 2022-04-22 02:40:26,989 Starting SageMaker Clarify Processing job
# 2022-04-22 02:40:26,990 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-04-22 02:40:26,990 Analysis result path: /opt/ml/processing/output
# 2022-04-22 02:40:26,990 This host is algo-1.
# 2022-04-22 02:40:26,990 This host is the leader.
# 2022-04-22 02:40:26,990 Number of hosts in the cluster is 1.
# 2022-04-22 02:40:27,160 Running Python / Pandas based analyzer.
# 2022-04-22 02:40:27,160 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-04-22 02:40:27,171 Loading dataset...
# 2022-04-22 02:40:27,280 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115831 entries, 0 to 115830
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     115831 non-null  int64
#  1   month                    115831 non-null  int64
#  2   day                      115831 non-null  int64
#  3   order                    115831 non-null  int64
#  4   country                  115831 non-null  int64
#  5   session ID               115831 non-null  int64
#  6   page 1 (main category)   115831 non-null  int64
#  7   page 2 (clothing model)  115831 non-null  int64
#  8   colour                   115831 non-null  int64
#  9   location                 115831 non-null  int64
#  10  model photography        115831 non-null  int64
#  11  price                    115831 non-null  int64
#  12  page                     115831 non-null  int64
# dtypes: int64(13)
# memory usage: 11.5 MB
# 2022-04-22 02:40:27,431 Spinning up shadow endpoint
# 2022-04-22 02:40:27,431 Creating endpoint-config with name sm-clarify-config-1650595227-46c8
# 2022-04-22 02:40:27,523 Creating endpoint: 'sm-clarify-clwcvr-Module8-Model-1650595227-e35a'
# 2022-04-22 02:40:27,835 Using endpoint name: sm-clarify-clwcvr-Module8-Model-1650595227-e35a
# 2022-04-22 02:40:27,835 Waiting for endpoint ...
# 2022-04-22 02:40:27,836 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-04-22 02:43:28,281 Endpoint is in service after 180 seconds
# 2022-04-22 02:43:28,282 Endpoint ready.
# 2022-04-22 02:43:28,282 ======================================
# 2022-04-22 02:43:28,282 Calculating post-training bias metrics
# 2022-04-22 02:43:28,282 ======================================
# 2022-04-22 02:43:28,282 Getting predictions from the endpoint
#
# 2022-04-22 02:43:33,077 We assume a prediction above 0.800 indicates 1 and below or equal indicates 0.
# 2022-04-22 02:43:33,079 Column price 2 with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,084 Column model photography with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,092 Column price 2 with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,096 Column None with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,099 AD metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 224, in AD
#     raise ValueError("Facet set is empty")
# ValueError: Facet set is empty
# 2022-04-22 02:43:33,183 DAR metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 179, in DAR
#     dar, _ = common.DLR(feature, sensitive_facet_index, positive_label_index, positive_predicted_label_index)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/common.py", line 245, in DLR
#     raise ValueError("DLR: Facet set is empty")
# ValueError: DLR: Facet set is empty
# 2022-04-22 02:43:33,184 DCA metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 96, in DCA
#     dca, _ = common.DCO(feature, sensitive_facet_index, positive_label_index, positive_predicted_label_index)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/common.py", line 191, in DCO
#     raise ValueError("DCO: Facet set is empty")
# ValueError: DCO: Facet set is empty
# 2022-04-22 02:43:33,185 DCR metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 116, in DCR
#     _, dcr = common.DCO(feature, sensitive_facet_index, positive_label_index, positive_predicted_label_index)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/common.py", line 191, in DCO
#     raise ValueError("DCO: Facet set is empty")
# ValueError: DCO: Facet set is empty
# 2022-04-22 02:43:33,189 DI metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 75, in DI
#     raise ValueError("Facet set is empty")
# ValueError: Facet set is empty
# 2022-04-22 02:43:33,192 DPPL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 41, in DPPL
#     return common.DPL(feature, sensitive_facet_index, positive_predicted_label_index)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/common.py", line 62, in DPL
#     raise ValueError("Facet set is empty.")
# ValueError: Facet set is empty.
# 2022-04-22 02:43:33,193 DRR metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 199, in DRR
#     _, drr = common.DLR(feature, sensitive_facet_index, positive_label_index, positive_predicted_label_index)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/common.py", line 245, in DLR
#     raise ValueError("DLR: Facet set is empty")
# ValueError: DLR: Facet set is empty
# 2022-04-22 02:43:33,194 FT metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 355, in FT
#     raise ValueError("Facet set is empty")
# ValueError: Facet set is empty
# 2022-04-22 02:43:33,194 RD metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 141, in RD
#     raise ValueError("Facet set is empty")
# ValueError: Facet set is empty
# 2022-04-22 02:43:33,195 TE metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/posttraining.py", line 302, in TE
#     raise ValueError("Facet set is empty")
# ValueError: Facet set is empty
# 2022-04-22 02:43:33,195 Stop using endpoint: sm-clarify-clwcvr-Module8-Model-1650595227-e35a
# 2022-04-22 02:43:33,195 Deleting endpoint configuration with name: sm-clarify-config-1650595227-46c8
# 2022-04-22 02:43:33,273 Deleting endpoint with name: sm-clarify-clwcvr-Module8-Model-1650595227-e35a
# 2022-04-22 02:43:33,462 Model endpoint delivered 0.40701 requests per second and a total of 2 requests over 5 seconds
# 2022-04-22 02:43:33,462 Stop using endpoint: None
# 2022-04-22 02:43:33,462 =====================================
# 2022-04-22 02:43:33,462 Calculating pre-training bias metrics
# 2022-04-22 02:43:33,462 =====================================
# 2022-04-22 02:43:33,464 Column price 2 with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,468 Column model photography with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,473 Column price 2 with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:33,557 CI metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 53, in CI
#     raise ValueError("CI: facet set is empty. Check that x[facet] has non-zero length.")
# ValueError: CI: facet set is empty. Check that x[facet] has non-zero length.
# 2022-04-22 02:43:33,561 DPL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 71, in DPL
#     return common.DPL(feature, sensitive_facet_index, positive_label_index)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/common.py", line 62, in DPL
#     raise ValueError("Facet set is empty.")
# ValueError: Facet set is empty.
# 2022-04-22 02:43:33,656 JS metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 114, in JS
#     raise ValueError("No instance of common facet found, dataset may be too small")
# ValueError: No instance of common facet found, dataset may be too small
# 2022-04-22 02:43:33,750 KL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 91, in KL
#     raise ValueError("No instance of common facet found, dataset may be too small")
# ValueError: No instance of common facet found, dataset may be too small
# 2022-04-22 02:43:33,844 KS metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 175, in KS
#     return LP_norm(label, sensitive_facet_index, np.inf)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 141, in LP_norm
#     raise ValueError("No instance of common facet found, dataset may be too small")
# ValueError: No instance of common facet found, dataset may be too small
# 2022-04-22 02:43:33,940 LP metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 132, in LP
#     return LP_norm(label, sensitive_facet_index, 2)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 141, in LP_norm
#     raise ValueError("No instance of common facet found, dataset may be too small")
# ValueError: No instance of common facet found, dataset may be too small
# 2022-04-22 02:43:34,033 TVD metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/report.py", line 297, in _categorical_metric_call_wrapper
#     group_variable=group_variable,
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 158, in TVD
#     Lp_res = LP_norm(label, sensitive_facet_index, 1)
#   File "/usr/local/lib/python3.7/site-packages/smclarify/bias/metrics/pretraining.py", line 141, in LP_norm
#     raise ValueError("No instance of common facet found, dataset may be too small")
# ValueError: No instance of common facet found, dataset may be too small
# 2022-04-22 02:43:34,034 ======================================
# 2022-04-22 02:43:34,034 Calculating bias statistics for report
# 2022-04-22 02:43:34,034 ======================================
# 2022-04-22 02:43:34,036 Column price 2 with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:34,040 Column model photography with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:34,045 Column price 2 with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:34,049 Column None with data uniqueness fraction 1.7266534865450528e-05 is classifed as a CATEGORICAL column
# 2022-04-22 02:43:34,063 Stop using endpoint: None
# 2022-04-22 02:43:34,347 jupyter nbconvert --to html --output /opt/ml/processing/output/report.html /opt/ml/processing/output/report.ipynb --template sagemaker-xai
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 349002 bytes to /opt/ml/processing/output/report.html
# 2022-04-22 02:43:35,319 HTML report '/opt/ml/processing/output/report.html' generated successfully.
# 2022-04-22 02:43:35,319 wkhtmltopdf -q /opt/ml/processing/output/report.html /opt/ml/processing/output/report.pdf
# 2022-04-22 02:43:35,833 PDF report '/opt/ml/processing/output/report.pdf' generated successfully.
# 2022-04-22 02:43:35,834 Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "price 2",
#         "facets": {
#             "model photography": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": null,
#                             "error": "Facet set is empty"
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.0
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": null,
#                             "error": "DLR: Facet set is empty"
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": null,
#                             "error": "DCO: Facet set is empty"
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": null,
#                             "error": "DCO: Facet set is empty"
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": null,
#                             "error": "Facet set is empty"
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": null,
#                             "error": "Facet set is empty."
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": null,
#                             "error": "DLR: Facet set is empty"
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": null,
#                             "error": "Facet set is empty"
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": null,
#                             "error": "Facet set is empty"
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": null,
#                             "error": "Facet set is empty"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "label": "price 2",
#         "facets": {
#             "model photography": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": 0.0
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": null,
#                             "error": "CI: facet set is empty. Check that x[facet] has non-zero length."
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": null,
#                             "error": "Facet set is empty."
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": null,
#                             "error": "No instance of common facet found, dataset may be too small"
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": null,
#                             "error": "No instance of common facet found, dataset may be too small"
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": null,
#                             "error": "No instance of common facet found, dataset may be too small"
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": null,
#                             "error": "No instance of common facet found, dataset may be too small"
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": null,
#                             "error": "No instance of common facet found, dataset may be too small"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# 2022-04-22 02:43:35,834 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %%
#View bias report
bias_report_output_path
# Out:
# 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/clwcvr-Module8-bias'

# %% [markdown]
# ## Exercise Part 5: Complete the ML model Fairness Training & Explaining Predictions

# %%
shap_config = clarify.SHAPConfig(
    baseline=[test_features.iloc[0].values.tolist()],
    num_samples=15,
    agg_method="mean_abs",
    save_local_shap_values=True,
)

explainability_output_path = "s3://{}/{}/clwcvr-Module8-explainability".format(bucket, prefix)
explainability_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=explainability_output_path,
    label="price 2",
    headers=training_data.columns.to_list(),
    dataset_type="text/csv",
)
# Out:
# DataConfig will be deprecated on 15 Mar 2022.s3_data_distribution_type parameter will no longer be supported. Everything else will remain as is in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
)
# Out:
# Job Name:  Clarify-Explainability-2022-04-22-02-43-58-853
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/train_data.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/clwcvr-Module8-explainability/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/clwcvr-Module8-explainability', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ..............................2022-04-22 02:48:53,063 logging.conf not found when configuring logging, using default logging configuration.
# 2022-04-22 02:48:53,064 Starting SageMaker Clarify Processing job
# 2022-04-22 02:48:53,064 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-04-22 02:48:53,064 Analysis result path: /opt/ml/processing/output
# 2022-04-22 02:48:53,064 This host is algo-1.
# 2022-04-22 02:48:53,064 This host is the leader.
# 2022-04-22 02:48:53,064 Number of hosts in the cluster is 1.
# 2022-04-22 02:48:53,221 Running Python / Pandas based analyzer.
# 2022-04-22 02:48:53,222 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-04-22 02:48:53,232 Loading dataset...
# 2022-04-22 02:48:53,335 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115831 entries, 0 to 115830
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     115831 non-null  int64
#  1   month                    115831 non-null  int64
#  2   day                      115831 non-null  int64
#  3   order                    115831 non-null  int64
#  4   country                  115831 non-null  int64
#  5   session ID               115831 non-null  int64
#  6   page 1 (main category)   115831 non-null  int64
#  7   page 2 (clothing model)  115831 non-null  int64
#  8   colour                   115831 non-null  int64
#  9   location                 115831 non-null  int64
#  10  model photography        115831 non-null  int64
#  11  price                    115831 non-null  int64
#  12  page                     115831 non-null  int64
# dtypes: int64(13)
# memory usage: 11.5 MB
# 2022-04-22 02:48:53,480 Spinning up shadow endpoint
# 2022-04-22 02:48:53,480 Creating endpoint-config with name sm-clarify-config-1650595733-090e
# 2022-04-22 02:48:53,558 Creating endpoint: 'sm-clarify-clwcvr-Module8-Model-1650595733-1c3c'
# 2022-04-22 02:48:53,827 Using endpoint name: sm-clarify-clwcvr-Module8-Model-1650595733-1c3c
# 2022-04-22 02:48:53,827 Waiting for endpoint ...
# 2022-04-22 02:48:53,827 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-04-22 02:51:54,251 Endpoint is in service after 180 seconds
# 2022-04-22 02:51:54,252 Endpoint ready.
# 2022-04-22 02:51:54,253 SHAP n_samples 15
# 2022-04-22 02:51:54,380 =====================================================
# 2022-04-22 02:51:54,380 Shap analyzer: explaining 115831 rows, 13 columns...
# 2022-04-22 02:51:54,380 =====================================================
#   0% (0 of 115831) |                     | Elapsed Time: 0:00:00 ETA:  --:--:--
#   2% (2953 of 115831) |                  | Elapsed Time: 0:00:30 ETA:   0:19:06
#   5% (6110 of 115831) |                  | Elapsed Time: 0:01:00 ETA:   0:17:22
#   8% (9324 of 115831) |#                 | Elapsed Time: 0:01:30 ETA:   0:16:34
#  11% (12897 of 115831) |#                | Elapsed Time: 0:02:00 ETA:   0:14:24
#  14% (16579 of 115831) |##               | Elapsed Time: 0:02:30 ETA:   0:13:28
#  17% (20288 of 115831) |##               | Elapsed Time: 0:03:00 ETA:   0:12:52
#  20% (23925 of 115831) |###              | Elapsed Time: 0:03:30 ETA:   0:12:38
#  23% (27616 of 115831) |####             | Elapsed Time: 0:04:00 ETA:   0:11:57
#  26% (31125 of 115831) |####             | Elapsed Time: 0:04:30 ETA:   0:12:04
#  29% (34665 of 115831) |#####            | Elapsed Time: 0:05:00 ETA:   0:11:28
#  32% (38146 of 115831) |#####            | Elapsed Time: 0:05:30 ETA:   0:11:09
#  36% (41748 of 115831) |######           | Elapsed Time: 0:06:00 ETA:   0:10:17
#  39% (45351 of 115831) |######           | Elapsed Time: 0:06:30 ETA:   0:09:46
#  42% (49021 of 115831) |#######          | Elapsed Time: 0:07:00 ETA:   0:09:06
#  45% (52681 of 115831) |#######          | Elapsed Time: 0:07:30 ETA:   0:08:37
#  48% (56212 of 115831) |########         | Elapsed Time: 0:08:00 ETA:   0:08:26
#  51% (59869 of 115831) |########         | Elapsed Time: 0:08:30 ETA:   0:07:39
#  54% (63078 of 115831) |#########        | Elapsed Time: 0:09:00 ETA:   0:08:13
#  57% (66269 of 115831) |#########        | Elapsed Time: 0:09:30 ETA:   0:07:46
#  60% (69547 of 115831) |##########       | Elapsed Time: 0:10:00 ETA:   0:07:03
#  62% (72749 of 115831) |##########       | Elapsed Time: 0:10:30 ETA:   0:06:43
#  65% (75937 of 115831) |###########      | Elapsed Time: 0:11:00 ETA:   0:06:15
#  68% (79135 of 115831) |###########      | Elapsed Time: 0:11:30 ETA:   0:05:44
#  71% (82510 of 115831) |############     | Elapsed Time: 0:12:00 ETA:   0:04:56
#  74% (85962 of 115831) |############     | Elapsed Time: 0:12:30 ETA:   0:04:19
#  77% (89442 of 115831) |#############    | Elapsed Time: 0:13:00 ETA:   0:03:47
#  80% (92956 of 115831) |#############    | Elapsed Time: 0:13:30 ETA:   0:03:15
#  83% (96577 of 115831) |##############   | Elapsed Time: 0:14:00 ETA:   0:02:39
#  86% (99949 of 115831) |##############   | Elapsed Time: 0:14:30 ETA:   0:02:21
#  89% (103662 of 115831) |##############  | Elapsed Time: 0:15:00 ETA:   0:01:38
#  92% (107342 of 115831) |##############  | Elapsed Time: 0:15:30 ETA:   0:01:09
#  95% (110964 of 115831) |############### | Elapsed Time: 0:16:00 ETA:   0:00:40
#  98% (114502 of 115831) |############### | Elapsed Time: 0:16:30 ETA:   0:00:11
# 100% (115831 of 115831) |################| Elapsed Time: 0:16:41 Time:  0:16:41
# 2022-04-22 03:08:35,673 getting explanations took 1001.29 seconds.
# 2022-04-22 03:08:35,673 ===================================================
# 2022-04-22 03:08:43,487 converting explanations to tabular took 7.81 seconds.
# 2022-04-22 03:08:43,487 ===================================================
# 2022-04-22 03:08:43,492 Wrote baseline used to compute explanations to: /opt/ml/processing/output/explanations_shap/baseline.csv
# 2022-04-22 03:08:45,423 Wrote 115831 local explanations to: /opt/ml/processing/output/explanations_shap/out.csv
# 2022-04-22 03:08:45,423 writing local explanations took 1.94 seconds.
# 2022-04-22 03:08:45,423 ===================================================
# 2022-04-22 03:08:45,431 aggregating local explanations took 0.01 seconds.
# 2022-04-22 03:08:45,431 ===================================================
# 2022-04-22 03:08:45,431 Shap analysis finished.
# 2022-04-22 03:08:45,432 Stop using endpoint: sm-clarify-clwcvr-Module8-Model-1650595733-1c3c
# 2022-04-22 03:08:45,432 Deleting endpoint configuration with name: sm-clarify-config-1650595733-090e
# 2022-04-22 03:08:45,531 Deleting endpoint with name: sm-clarify-clwcvr-Module8-Model-1650595733-1c3c
# 2022-04-22 03:08:45,647 Model endpoint delivered 114.55228 requests per second and a total of 115833 requests over 1011 seconds
# 2022-04-22 03:08:58,844 Stop using endpoint: None
# 2022-04-22 03:09:23,655 jupyter nbconvert --to html --output /opt/ml/processing/output/report.html /opt/ml/processing/output/report.ipynb --template sagemaker-xai
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 621353 bytes to /opt/ml/processing/output/report.html
# 2022-04-22 03:09:24,672 HTML report '/opt/ml/processing/output/report.html' generated successfully.
# 2022-04-22 03:09:24,672 wkhtmltopdf -q /opt/ml/processing/output/report.html /opt/ml/processing/output/report.pdf
# 2022-04-22 03:09:25,239 PDF report '/opt/ml/processing/output/report.pdf' generated successfully.
# 2022-04-22 03:09:25,239 Collected analyses:
# {
#     "version": "1.0",
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "global_shap_values": {
#                     "year": 0.04673260478766828,
#                     "month": 0.04659064506003927,
#                     "day": 0.04651678283709871,
#                     "order": 0.04660212451220549,
#                     "country": 0.046253250129609805,
#                     "session ID": 0.046647634127960004,
#                     "page 1 (main category)": 0.10124742482668356,
#                     "page 2 (clothing model)": 0.046969634005154325,
#                     "colour": 0.048580574762764964,
#                     "location": 0.046980526702618194,
#                     "model photography": 0.04669407381889736,
#                     "price": 0.39453070416689384,
#                     "page": 0.09811777948058864
#                 },
#                 "expected_value": 0.00025773694505915046
#             }
#         }
#     }
# }
# 2022-04-22 03:09:25,240 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %%
#View the explainability report
explainability_output_path
# Out:
# 's3://clwcvr-sagemaker/sagemaker/clwcvr_M8_DataBias/clwcvr-Module8-explainability'

# %% [markdown]
# ## Analysis of local explanations

# %%
local_explanations_out = pd.read_csv(explainability_output_path + "/explanations_shap/out.csv")
feature_names = [str.replace(c, "_label0", "") for c in local_explanations_out.columns.to_series()]
local_explanations_out.columns = feature_names

selected_example = 111
print(
    "Example number:",
    selected_example,
    "\nwith model prediction:",
    sum(local_explanations_out.iloc[selected_example]) > 0,
)
print("\nFeature values -- Label", training_data.iloc[selected_example])
local_explanations_out.iloc[selected_example].plot(
    kind="bar", title="Local explanation for the example number " + str(selected_example), rot=90
)
# Out:
# Example number: 111
# with model prediction: False
#
# Feature values -- Label price 2                       0
# year                       2008
# month                         4
# day                          16
# order                         5
# country                      29
# session ID                 4001
# page 1 (main category)        2
# page 2 (clothing model)      57
# colour                        7
# location                      2
# model photography             1
# price                        38
# page                          2
# Name: 27348, dtype: int64
